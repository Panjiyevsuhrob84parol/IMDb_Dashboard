# %%
import requests
from bs4 import BeautifulSoup
import time
url = "https://www.imdb.com/list/ls048276758/?view=detailed"

headers = {
    "accept-language": "en-US,en;q=0.9,nl;q=0.8,de;q=0.7",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}   

data = requests.get(url=url, headers=headers)
print(data.status_code)
time.sleep(5)
soup = BeautifulSoup(data.text, 'lxml')
# print(soup.prettify())
# Out:
# 200

# %%
movies = soup.find_all("li", class_='ipc-metadata-list-summary-item')

# %%
movies
# Out:
# [<li class="ipc-metadata-list-summary-item"><div class="ipc-metadata-list-summary-item__c"><div class="ipc-metadata-list-summary-item__tc"><span aria-disabled="false" class="ipc-metadata-list-summary-item__t ipc-btn--not-interactable"></span><div class="sc-fc35a1ef-1 lmHCrT dli-parent"><div class="sc-fc35a1ef-0 hTMtRz"><div class="sc-d0224b4e-0 jfogmY dli-poster-container"><div class="ipc-poster ipc-poster--base ipc-poster--media-radius ipc-poster--wl-true ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group"><div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--media-radius ipc-media--base ipc-media--poster-s ipc-poster__poster-image ipc-media__img" style="width:100%"><img alt="Marlon Brando in The Godfather (1972)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BNGEwYjgwO
# ...

# %%
len(movies)
# Out:
# 25

# %%
movies[0]
# Out:
# <li class="ipc-metadata-list-summary-item"><div class="ipc-metadata-list-summary-item__c"><div class="ipc-metadata-list-summary-item__tc"><span aria-disabled="false" class="ipc-metadata-list-summary-item__t ipc-btn--not-interactable"></span><div class="sc-fc35a1ef-1 lmHCrT dli-parent"><div class="sc-fc35a1ef-0 hTMtRz"><div class="sc-d0224b4e-0 jfogmY dli-poster-container"><div class="ipc-poster ipc-poster--base ipc-poster--media-radius ipc-poster--wl-true ipc-poster--dynamic-width ipc-sub-grid-item ipc-sub-grid-item--span-2" role="group"><div class="ipc-media ipc-media--poster-27x40 ipc-image-media-ratio--poster-27x40 ipc-media--media-radius ipc-media--base ipc-media--poster-s ipc-poster__poster-image ipc-media__img" style="width:100%"><img alt="Marlon Brando in The Godfather (1972)" class="ipc-image" loading="lazy" sizes="50vw, (min-width: 480px) 34vw, (min-width: 600px) 26vw, (min-width: 1024px) 16vw, (min-width: 1280px) 16vw" src="https://m.media-amazon.com/images/M/MV5BNGEwYjgwOG
# ...

# %%
movies[0].find('h3', class_="ipc-title__text").text
# Out:
# '1. The Godfather'

# %%
movie_names = []
ratings = []
urls=[]
stars = []
directors = []
for movie in movies:
    name = movie.find('h3', class_="ipc-title__text").text
    movie_names.append(name)

# %%
name = '1. The Godfather'
name.split(".")[1].strip()
# Out:
# 'The Godfather'

# %%
movie_names
# Out:
# ['1. The Godfather',
#  '2. Tokyo Story',
#  '3. Seven Samurai',
#  '4. The Godfather Part II',
#  '5. Casablanca',
#  '6. Citizen Kane',
#  '7. Lawrence of Arabia',
#  '8. 12 Angry Men',
#  '9. Sunset Boulevard',
#  '10. Shoah',
#  '11. Ordet',
#  '12. All About Eve',
#  '13. Dekalog',
#  '14. Pulp Fiction',
#  '15. City Lights',
#  '16. Ugetsu',
#  "17. Singin' in the Rain",
#  "18. Schindler's List",
#  '19. The 400 Blows',
#  '20. Goodfellas',
#  '21. Children of Paradise',
#  '22. Modern Times',
#  '23. Psycho',
#  "24. One Flew Over the Cuckoo's Nest",
#  '25. M']

# %%
movies[0].find("h3", class_='ipc-title__text').text
# Out:
# '1. The Godfather'
